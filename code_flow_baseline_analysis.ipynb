# %%
import warnings

warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from matplotlib.ticker import PercentFormatter
plt.rcParams.update({ "figure.figsize" : (8, 5),"axes.facecolor" : "white", "axes.edgecolor":  "black"})
plt.rcParams["figure.facecolor"]= "w"
pd.plotting.register_matplotlib_converters()
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
# read external data
df_test = pd.read_csv('~/Downloads/ds-NeueFischer-Bootcamp/phase3_machine_learning_basics/Air_Polution_Analysis/data/Test.csv')
df_train = pd.read_csv('~/Downloads/ds-NeueFischer-Bootcamp/phase3_machine_learning_basics/Air_Polution_Analysis/data/Train.csv')
#df_train.info()
#df_train.head()
#df_train.describe()
#print(df_train.dtypes)
#non_null_counts = df_train.notnull().sum()
#print(non_null_counts)
#missing_values = df_train.isnull()
#print(missing_values)
#df_train.columns
df_train.columns
# Out:
# Index(['Place_ID X Date', 'Date', 'Place_ID', 'target', 'target_min',
#        'target_max', 'target_variance', 'target_count',
#        'precipitable_water_entire_atmosphere',
#        'relative_humidity_2m_above_ground',
#        'specific_humidity_2m_above_ground', 'temperature_2m_above_ground',
#        'u_component_of_wind_10m_above_ground',
#        'v_component_of_wind_10m_above_ground',
#        'L3_NO2_NO2_column_number_density',
#        'L3_NO2_NO2_slant_column_number_density',
#        'L3_NO2_absorbing_aerosol_index', 'L3_NO2_cloud_fraction',
#        'L3_NO2_sensor_altitude', 'L3_NO2_sensor_azimuth_angle',
#        'L3_NO2_sensor_zenith_angle', 'L3_NO2_solar_azimuth_angle',
#        'L3_NO2_solar_zenith_angle',
#        'L3_NO2_stratospheric_NO2_column_number_density',
#        'L3_NO2_tropopause_pressure',
#        'L3_NO2_tropospheric_NO2_column_number_density',
#        'L3_O3_O3_column_number_density', 'L3_O3_O3_effective_temperature',
#        'L3_O3_cloud_fraction', 'L3_O3_sensor_azimuth_angle',
#        'L3_O3_sensor_zenith_angle', 'L3_O3_solar_azimuth_angle',
#        'L3_O3_solar_zenith_angle', 'L3_CO_CO_column_number_density',
#        'L3_CO_H2O_column_number_density', 'L3_CO_cloud_height',
#        'L3_CO_sensor_altitude', 'L3_CO_sensor_azimuth_angle',
#        'L3_CO_sensor_zenith_angle', 'L3_CO_solar_azimuth_angle',
#        'L3_CO_solar_zenith_angle', 'L3_HCHO_HCHO_slant_column_number_density',
#        'L3_HCHO_cloud_fraction', 'L3_HCHO_sensor_azimuth_angle',
#        'L3_HCHO_sensor_zenith_angle', 'L3_HCHO_solar_azimuth_angle',
#        'L3_HCHO_solar_zenith_angle',
#        'L3_HCHO_tropospheric_HCHO_column_number_density',
#        'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
#        'L3_CLOUD_cloud_base_height', 'L3_CLOUD_cloud_base_pressure',
#        'L3_CLOUD_cloud_fraction', 'L3_CLOUD_cloud_optical_depth',
#        'L3_CLOUD_cloud_top_height', 'L3_CLOUD_cloud_top_pressure',
#        'L3_CLOUD_sensor_azimuth_angle', 'L3_CLOUD_sensor_zenith_angle',
#        'L3_CLOUD_solar_azimuth_angle', 'L3_CLOUD_solar_zenith_angle',
#        'L3_CLOUD_surface_albedo', 'L3_AER_AI_absorbing_aerosol_index',
#        'L3_AER_AI_sensor_altitude', 'L3_AER_AI_sensor_azimuth_angle',
#        'L3_AER_AI_sensor_zenith_angle', 'L3_AER_AI_solar_azimuth_angle',
#        'L3_AER_AI_solar_zenith_angle', 'L3_SO2_SO2_column_number_density',
#        'L3_SO2_SO2_column_number_density_amf',
#        'L3_SO2_SO2_slant_column_number_density',
#        'L3_SO2_absorbing_aerosol_index', 'L3_SO2_cloud_fraction',
#        'L3_SO2_sensor_azimuth_angle', 'L3_SO2_sensor_zenith_angle',
#        'L3_SO2_solar_azimuth_angle', 'L3_SO2_solar_zenith_angle',
#        'L3_CH4_CH4_column_volume_mixing_ratio_dry_air',
#        'L3_CH4_aerosol_height', 'L3_CH4_aerosol_optical_depth',
#        'L3_CH4_sensor_azimuth_angle', 'L3_CH4_sensor_zenith_angle',
#        'L3_CH4_solar_azimuth_angle', 'L3_CH4_solar_zenith_angle'],
#       dtype='object')

# %%
#print(missing_percentage.sort_values(ascending=False))
#Remove Features with Too Many Missing Values, If a feature has more than a certain threshold of missing values (e.g., >50%), it might be irrelevant for our model
threshold = 0.5
missing_percentage_train = df_train.isnull().mean() * 100  # Calculate % of missing values for each column
Filtered_df_train = df_train.loc[:, missing_percentage_train < (threshold * 100)]
Filtered_df_train.head()
# Out:
#         Place_ID X Date        Date Place_ID  target  target_min  target_max  \
# 0  010Q650 X 2020-01-02  2020-01-02  010Q650  38.000      23.000      53.000
# 1  010Q650 X 2020-01-03  2020-01-03  010Q650  39.000      25.000      63.000
# 2  010Q650 X 2020-01-04  2020-01-04  010Q650  24.000       8.000      56.000
# 3  010Q650 X 2020-01-05  2020-01-05  010Q650  49.000      10.000      55.000
# 4  010Q650 X 2020-01-06  2020-01-06  010Q650  21.000       9.000      52.000
#
#    target_variance  target_count  precipitable_water_entire_atmosphere  \
# 0          769.500            92                                11.000
# 1         1319.850            91                                14.600
# 2         1181.960            96                                16.400
# 3         1113.670            96                                 6.912
# 4         1164.820            95                                13.900
#
#    relative_humidity_2m_above_ground  ...  L3_AER_AI_solar_zenith_angle  \
# 0                             60.200  ...                        22.358
# 1                             48.800  ...                        28.615
# 2                             33.400  ...                        34.297
# 3                             21.300  ...                        30.545
# 4                             44.700  ...                        26.900
#
#    L3_SO2_SO2_column_number_density  L3_SO2_SO2_column_number_density_amf  \
# 0                            -0.000                                 0.313
# 1                             0.000                                 0.434
# 2                             0.000                                 0.357
# 3                             0.000                                 0.585
# 4                             0.000                                 0.408
#
#    L3_SO2_SO2_slant_column_number_density  L3_SO2_absorbing_aerosol_index  \
# 0                                  -0.000                          -1.861
# 1                                   0.000                          -1.453
# 2                                   0.000                          -1.573
# 3                                   0.000                          -1.239
# 4                                   0.000                           0.202
#
#    L3_SO2_cloud_fraction  L3_SO2_sensor_azimuth_angle  \
# 0                  0.000                       76.536
# 1                  0.059                      -14.708
# 2                  0.082                     -105.201
# 3                  0.121                     -104.334
# 4                  0.038                       58.850
#
#    L3_SO2_sensor_zenith_angle  L3_SO2_solar_azimuth_angle  \
# 0                      38.593                     -61.753
# 1                      59.625                     -67.694
# 2                      49.840                     -78.343
# 3                      29.181                     -73.897
# 4                       0.797                     -68.612
#
#    L3_SO2_solar_zenith_angle
# 0                     22.364
# 1                     28.615
# 2                     34.297
# 3                     30.545
# 4                     26.900
#
# [5 rows x 75 columns]

# %%
Filtered_df_train.drop(['Place_ID X Date', 'Date', 'Place_ID'], axis=1, inplace=True)

# %%
Filtered_df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30557 entries, 0 to 30556
# Data columns (total 72 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   target                                               30557 non-null  float64
#  1   target_min                                           30557 non-null  float64
#  2   target_max                                           30557 non-null  float64
#  3   target_variance                                      30557 non-null  float64
#  4   target_count                                         30557 non-null  int64
#  5   precipitable_water_entire_atmosphere                 30557 non-null  float64
#  6   relative_humidity_2m_above_ground                    30557 non-null  float64
#  7   specific_humidity_2m_above_ground                    30557 non-null  float64
#  8   temperature_2m_above_ground                          30557 non-null  float64
#  9   u_component_of_wind_10m_above_ground                 30557 non-null  float64
#  10  v_component_of_wind_10m_above_ground                 30557 non-null  float64
#  11  L3_NO2_NO2_column_number_density                     28368 non-null  float64
#  12  L3_NO2_NO2_slant_column_number_density               28368 non-null  float64
#  13  L3_NO2_absorbing_aerosol_index                       28368 non-null  float64
#  14  L3_NO2_cloud_fraction                                28368 non-null  float64
#  15  L3_NO2_sensor_altitude                               28368 non-null  float64
#  16  L3_NO2_sensor_azimuth_angle                          28367 non-null  float64
#  17  L3_NO2_sensor_zenith_angle                           28367 non-null  float64
#  18  L3_NO2_solar_azimuth_angle                           28367 non-null  float64
#  19  L3_NO2_solar_zenith_angle                            28367 non-null  float64
#  20  L3_NO2_stratospheric_NO2_column_number_density       28367 non-null  float64
#  21  L3_NO2_tropopause_pressure                           28367 non-null  float64
#  22  L3_NO2_tropospheric_NO2_column_number_density        21888 non-null  float64
#  23  L3_O3_O3_column_number_density                       30274 non-null  float64
#  24  L3_O3_O3_effective_temperature                       30274 non-null  float64
#  25  L3_O3_cloud_fraction                                 30274 non-null  float64
#  26  L3_O3_sensor_azimuth_angle                           30274 non-null  float64
#  27  L3_O3_sensor_zenith_angle                            30274 non-null  float64
#  28  L3_O3_solar_azimuth_angle                            30274 non-null  float64
#  29  L3_O3_solar_zenith_angle                             30274 non-null  float64
#  30  L3_CO_CO_column_number_density                       25134 non-null  float64
#  31  L3_CO_H2O_column_number_density                      25134 non-null  float64
#  32  L3_CO_cloud_height                                   25134 non-null  float64
#  33  L3_CO_sensor_altitude                                25134 non-null  float64
#  34  L3_CO_sensor_azimuth_angle                           25134 non-null  float64
#  35  L3_CO_sensor_zenith_angle                            25134 non-null  float64
#  36  L3_CO_solar_azimuth_angle                            25134 non-null  float64
#  37  L3_CO_solar_zenith_angle                             25134 non-null  float64
#  38  L3_HCHO_HCHO_slant_column_number_density             23132 non-null  float64
#  39  L3_HCHO_cloud_fraction                               23132 non-null  float64
#  40  L3_HCHO_sensor_azimuth_angle                         23132 non-null  float64
#  41  L3_HCHO_sensor_zenith_angle                          23132 non-null  float64
#  42  L3_HCHO_solar_azimuth_angle                          23132 non-null  float64
#  43  L3_HCHO_solar_zenith_angle                           23132 non-null  float64
#  44  L3_HCHO_tropospheric_HCHO_column_number_density      23132 non-null  float64
#  45  L3_HCHO_tropospheric_HCHO_column_number_density_amf  23132 non-null  float64
#  46  L3_CLOUD_cloud_base_height                           29035 non-null  float64
#  47  L3_CLOUD_cloud_base_pressure                         29035 non-null  float64
#  48  L3_CLOUD_cloud_fraction                              30183 non-null  float64
#  49  L3_CLOUD_cloud_optical_depth                         29035 non-null  float64
#  50  L3_CLOUD_cloud_top_height                            29035 non-null  float64
#  51  L3_CLOUD_cloud_top_pressure                          29035 non-null  float64
#  52  L3_CLOUD_sensor_azimuth_angle                        30183 non-null  float64
#  53  L3_CLOUD_sensor_zenith_angle                         30183 non-null  float64
#  54  L3_CLOUD_solar_azimuth_angle                         30183 non-null  float64
#  55  L3_CLOUD_solar_zenith_angle                          30183 non-null  float64
#  56  L3_CLOUD_surface_albedo                              29035 non-null  float64
#  57  L3_AER_AI_absorbing_aerosol_index                    30360 non-null  float64
#  58  L3_AER_AI_sensor_altitude                            30360 non-null  float64
#  59  L3_AER_AI_sensor_azimuth_angle                       30360 non-null  float64
#  60  L3_AER_AI_sensor_zenith_angle                        30360 non-null  float64
#  61  L3_AER_AI_solar_azimuth_angle                        30360 non-null  float64
#  62  L3_AER_AI_solar_zenith_angle                         30360 non-null  float64
#  63  L3_SO2_SO2_column_number_density                     23320 non-null  float64
#  64  L3_SO2_SO2_column_number_density_amf                 23320 non-null  float64
#  65  L3_SO2_SO2_slant_column_number_density               23320 non-null  float64
#  66  L3_SO2_absorbing_aerosol_index                       23249 non-null  float64
#  67  L3_SO2_cloud_fraction                                23320 non-null  float64
#  68  L3_SO2_sensor_azimuth_angle                          23320 non-null  float64
#  69  L3_SO2_sensor_zenith_angle                           23320 non-null  float64
#  70  L3_SO2_solar_azimuth_angle                           23320 non-null  float64
#  71  L3_SO2_solar_zenith_angle                            23320 non-null  float64
# dtypes: float64(71), int64(1)
# memory usage: 16.8 MB

# %%
threshold = 0.5
missing_percentage_test = df_test.isnull().mean() * 100  # Calculate % of missing values for each column
Filtered_df_test = df_test.loc[:, missing_percentage_test < (threshold * 100)]
Filtered_df_test.info()
# Check data types of each column
#print(df_test.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16136 entries, 0 to 16135
# Data columns (total 70 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Place_ID X Date                                      16136 non-null  object
#  1   Date                                                 16136 non-null  object
#  2   Place_ID                                             16136 non-null  object
#  3   precipitable_water_entire_atmosphere                 16136 non-null  float64
#  4   relative_humidity_2m_above_ground                    16136 non-null  float64
#  5   specific_humidity_2m_above_ground                    16136 non-null  float64
#  6   temperature_2m_above_ground                          16136 non-null  float64
#  7   u_component_of_wind_10m_above_ground                 16136 non-null  float64
#  8   v_component_of_wind_10m_above_ground                 16136 non-null  float64
#  9   L3_NO2_NO2_column_number_density                     14809 non-null  float64
#  10  L3_NO2_NO2_slant_column_number_density               14809 non-null  float64
#  11  L3_NO2_absorbing_aerosol_index                       14809 non-null  float64
#  12  L3_NO2_cloud_fraction                                14809 non-null  float64
#  13  L3_NO2_sensor_altitude                               14809 non-null  float64
#  14  L3_NO2_sensor_azimuth_angle                          14809 non-null  float64
#  15  L3_NO2_sensor_zenith_angle                           14809 non-null  float64
#  16  L3_NO2_solar_azimuth_angle                           14809 non-null  float64
#  17  L3_NO2_solar_zenith_angle                            14809 non-null  float64
#  18  L3_NO2_stratospheric_NO2_column_number_density       14809 non-null  float64
#  19  L3_NO2_tropopause_pressure                           14809 non-null  float64
#  20  L3_NO2_tropospheric_NO2_column_number_density        11163 non-null  float64
#  21  L3_O3_O3_column_number_density                       15922 non-null  float64
#  22  L3_O3_O3_effective_temperature                       15922 non-null  float64
#  23  L3_O3_cloud_fraction                                 15922 non-null  float64
#  24  L3_O3_sensor_azimuth_angle                           15922 non-null  float64
#  25  L3_O3_sensor_zenith_angle                            15922 non-null  float64
#  26  L3_O3_solar_azimuth_angle                            15922 non-null  float64
#  27  L3_O3_solar_zenith_angle                             15922 non-null  float64
#  28  L3_CO_CO_column_number_density                       13135 non-null  float64
#  29  L3_CO_H2O_column_number_density                      13135 non-null  float64
#  30  L3_CO_cloud_height                                   13135 non-null  float64
#  31  L3_CO_sensor_altitude                                13135 non-null  float64
#  32  L3_CO_sensor_azimuth_angle                           13135 non-null  float64
#  33  L3_CO_sensor_zenith_angle                            13135 non-null  float64
#  34  L3_CO_solar_azimuth_angle                            13135 non-null  float64
#  35  L3_CO_solar_zenith_angle                             13135 non-null  float64
#  36  L3_HCHO_HCHO_slant_column_number_density             11916 non-null  float64
#  37  L3_HCHO_cloud_fraction                               11916 non-null  float64
#  38  L3_HCHO_sensor_azimuth_angle                         11916 non-null  float64
#  39  L3_HCHO_sensor_zenith_angle                          11916 non-null  float64
#  40  L3_HCHO_solar_azimuth_angle                          11916 non-null  float64
#  41  L3_HCHO_solar_zenith_angle                           11916 non-null  float64
#  42  L3_HCHO_tropospheric_HCHO_column_number_density      11916 non-null  float64
#  43  L3_HCHO_tropospheric_HCHO_column_number_density_amf  11916 non-null  float64
#  44  L3_CLOUD_cloud_base_height                           15186 non-null  float64
#  45  L3_CLOUD_cloud_base_pressure                         15186 non-null  float64
#  46  L3_CLOUD_cloud_fraction                              15874 non-null  float64
#  47  L3_CLOUD_cloud_optical_depth                         15186 non-null  float64
#  48  L3_CLOUD_cloud_top_height                            15186 non-null  float64
#  49  L3_CLOUD_cloud_top_pressure                          15186 non-null  float64
#  50  L3_CLOUD_sensor_azimuth_angle                        15874 non-null  float64
#  51  L3_CLOUD_sensor_zenith_angle                         15874 non-null  float64
#  52  L3_CLOUD_solar_azimuth_angle                         15874 non-null  float64
#  53  L3_CLOUD_solar_zenith_angle                          15874 non-null  float64
#  54  L3_CLOUD_surface_albedo                              15186 non-null  float64
#  55  L3_AER_AI_absorbing_aerosol_index                    16043 non-null  float64
#  56  L3_AER_AI_sensor_altitude                            16043 non-null  float64
#  57  L3_AER_AI_sensor_azimuth_angle                       16043 non-null  float64
#  58  L3_AER_AI_sensor_zenith_angle                        16043 non-null  float64
#  59  L3_AER_AI_solar_azimuth_angle                        16043 non-null  float64
#  60  L3_AER_AI_solar_zenith_angle                         16043 non-null  float64
#  61  L3_SO2_SO2_column_number_density                     11963 non-null  float64
#  62  L3_SO2_SO2_column_number_density_amf                 11963 non-null  float64
#  63  L3_SO2_SO2_slant_column_number_density               11963 non-null  float64
#  64  L3_SO2_absorbing_aerosol_index                       11934 non-null  float64
#  65  L3_SO2_cloud_fraction                                11963 non-null  float64
#  66  L3_SO2_sensor_azimuth_angle                          11963 non-null  float64
#  67  L3_SO2_sensor_zenith_angle                           11963 non-null  float64
#  68  L3_SO2_solar_azimuth_angle                           11963 non-null  float64
#  69  L3_SO2_solar_zenith_angle                            11963 non-null  float64
# dtypes: float64(67), object(3)
# memory usage: 8.6+ MB

# %%
Filtered_df_test.drop(['Place_ID X Date', 'Date', 'Place_ID'], axis=1, inplace=True)

# %%
#split df_train into features (X_train) and target (y_train), and then split df_train further into train and validation sets using train_test_split. 
# Then, you can use df_test only for predictions after the model is trained.

from sklearn.model_selection import train_test_split

# Splitting the training data (df_train)
X_train = Filtered_df_train.drop('target', axis=1)  # Features of the training set
y_train = Filtered_df_train['target']  # Target variable for the training set

# Split the df_train into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# df_test will only be used for prediction, as it does not contain a target variable
X_test = Filtered_df_test  # Test features for making predictions

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the Random Forest model
model = RandomForestRegressor(max_depth=3,random_state=42)

# %%
# Fit the model on the training data (train the modeL)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=3, random_state=42)

# %%
#Evaluate the Model Using Validation Data:
y_val_pred = model.predict(X_val)

# %%
#Evaluate the performance of the model using appropriate regression metrics (e.g., Mean Squared Error (MSE) or R-squared):
from sklearn.metrics import mean_squared_error, r2_score

mse_val = mean_squared_error(y_val, y_val_pred)
r2_val = r2_score(y_val, y_val_pred)

print(f"Validation Mean Squared Error (MSE): {mse_val}")
print(f"Validation R-squared (R²): {r2_val}")
# Out:
# Validation Mean Squared Error (MSE): 501.00084261626137
# Validation R-squared (R²): 0.7722830313520903

# %%
#Model Prediction on Test Data: cannot compute test data because there are target missing columns.
#y_test_pred = model.predict(X_test)
#print(y_test_pred)

# %% [markdown]
# stoped here

# %%
# Fill missing values with mean
#Filtered_df_train.fillna(Filtered_df_train.mean(), inplace=True)  # For numeric columns
#print(Filtered_df_train.isnull().sum()) #Ensure that 0 is printed for all numeric columns

# Fill missing values with mean
#Filtered_df_test.fillna(Filtered_df_test.mean(), inplace=True)  # For numeric columns
#print(Filtered_df_test.isnull().sum()) #Ensure that 0 is printed for all numeric columns
# Out:
# target                                  0
# precipitable_water_entire_atmosphere    0
# relative_humidity_2m_above_ground       0
# specific_humidity_2m_above_ground       0
# temperature_2m_above_ground             0
#                                        ..
# L3_SO2_cloud_fraction                   0
# L3_SO2_sensor_azimuth_angle             0
# L3_SO2_sensor_zenith_angle              0
# L3_SO2_solar_azimuth_angle              0
# L3_SO2_solar_zenith_angle               0
# Length: 68, dtype: int64

# %%
#Scale/normalize the data => no need to scale for random forest
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#Filtered_df_train_scaled = pd.DataFrame(scaler.fit_transform(Filtered_df_train), columns=Filtered_df_train.columns)

# %% [markdown]
# Key Notes:
#
#     Training Data (df_train): The target column exists here, so we separate the features and the target, then split the data into training and validation sets using train_test_split.
#         X_train: Features for training.
#         y_train: Target for training.
#         X_val, y_val: Validation set, used to evaluate the model's performance during training.
#
#     Test Data (df_test): Since the test data does not contain the target column, you only need the features (X_test) for predictions. The model will predict on X_test after it’s trained.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Residuals for validation data
residuals_val = y_val - y_val_pred

# %% [markdown]
# Homoscedasticity (Constant Variance):
#
#    The spread of residuals should be roughly constant across the range of predicted values.
#     If you see a pattern like a "fan" or a "funnel" shape, it suggests heteroscedasticity (non-constant variance), which means the model’s errors are not consistent across all levels of the predicted values.
#     **In our case, the upper catter plot show clear patterns of heteroscedasticity**
#
# If there’s a clear trend (e.g., increasing/decreasing residuals), this might indicate underfitting or the model not capturing the data's complexity well.

# %%
# Calculate residuals for training set
y_train_pred = model.predict(X_train)
residuals_train = y_train - y_train_pred

# Calculate residuals for validation set
y_val_pred = model.predict(X_val)
residuals_val = y_val - y_val_pred

# %%
# Plot histogram of residuals
plt.figure(figsize=(10, 6))
sns.histplot(residuals_val, kde=True, color='blue')
plt.title('Histogram of Residuals (Validation Data)')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.ylim(0,1700)
plt.xlim(-100, 700)
plt.show()
## In our case, no true `y_test`, so we can’t calculate residuals directly for test set
# If we get true values for y_test, we can proceed like for validation data

plt.figure(figsize=(10, 6))
sns.histplot(residuals_train, kde=True, color='blue')
plt.title('Histogram of Residuals (Train Data)')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.ylim(0,1700)
plt.xlim(-100, 700)
plt.show()

# %% [markdown]
# Normal distirbution of the residuals for the histogram and the Q-Q plot

# %%
import scipy.stats as stats

# Q-Q plot for validation residuals
plt.figure(figsize=(10, 6))
stats.probplot(residuals_val, dist="norm", plot=plt)
plt.title('Q-Q Plot of Residuals (Validation Data)')
plt.ylim(-200,700)
plt.xlim(-5, 4)
plt.show()

# Q-Q plot for validation residuals
plt.figure(figsize=(10, 6))
stats.probplot(residuals_train, dist="norm", plot=plt)
plt.title('Q-Q Plot of Residuals (Train Data)')
plt.ylim(-200,700)
plt.xlim(-5, 4)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot residuals for train and validation data
plt.figure(figsize=(14, 6))

# Plot training residuals
plt.subplot(1, 2, 1)
plt.scatter(y_train_pred, residuals_train, color='blue', alpha=0.5)
plt.axhline(y=0, color='black', linestyle='--')
plt.title('Residuals for Training Set')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.ylim(-100,700)

# Plot validation residuals
plt.subplot(1, 2, 2)
plt.scatter(y_val_pred, residuals_val, color='green', alpha=0.5)
plt.axhline(y=0, color='black', linestyle='--')
plt.title('Residuals for Validation Set')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.tight_layout()
plt.ylim(-100,700)
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Evaluate performance on the training data
mse_train = mean_squared_error(y_train, y_train_pred)
r2_train = r2_score(y_train, y_train_pred)

# Evaluate performance on the validation data
mse_val = mean_squared_error(y_val, y_val_pred)
r2_val = r2_score(y_val, y_val_pred)

print(f"Training Mean Squared Error (MSE): {mse_train}")
print(f"Training R-squared (R²): {r2_train}")
print(f"Validation Mean Squared Error (MSE): {mse_val}")
print(f"Validation R-squared (R²): {r2_val}")
# Out:
# Training Mean Squared Error (MSE): 470.0675366813696
# Training R-squared (R²): 0.7858319474590169
# Validation Mean Squared Error (MSE): 501.00084261626137
# Validation R-squared (R²): 0.7722830313520903

# %%
import matplotlib.pyplot as plt

# R² scores
r2_training = 0.7858319474590169
r2_validation = 0.7722830313520903

# Plotting R²
plt.figure(figsize=(8, 5))
plt.bar(['Training', 'Validation'], [r2_training, r2_validation], color=['skyblue', 'orange'])
plt.ylabel('R² Score')
plt.title('Comparison of R² Scores')
plt.ylim(0, 1)  # Ensures scale is consistent for R²

# Show plot
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
# MSE scores
mse_training = 470.0675366813696
mse_validation = 501.00084261626137

# Plotting MSE
plt.figure(figsize=(8, 5))
plt.bar(['Training', 'Validation'], [mse_training, mse_validation], color=['skyblue', 'orange'])
plt.ylabel('Mean Squared Error')
plt.title('Comparison of MSE')
plt.ylim(0, max(mse_training, mse_validation) + 50)  # Adjust for better visual spacing

# Show plot
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# Overfitting: The large difference between training and validation MSE and R² suggests that your model may be overfitting the training data.
#
#     Training R²: 0.94 is quite high, indicating that the model fits the training data very well.
#     Validation R²: 0.58 is much lower, indicating that the model is not generalizing well to new, unseen data. This drop in performance is typically a sign of overfitting.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Get feature importances from the trained model
importances = model.feature_importances_

# Create a DataFrame to view feature importances alongside feature names
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': importances
})

# Sort the DataFrame based on importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Feature Importance')
plt.title('Feature Importance from RandomForestRegressor')
plt.show()

# Display the sorted feature importance table
print(feature_importance_df)
# Out:
#                                  Feature  Importance
# 1                             target_max       0.701
# 0                             target_min       0.297
# 2                        target_variance       0.002
# 3                           target_count       0.000
# 4   precipitable_water_entire_atmosphere       0.000
# ..                                   ...         ...
# 66                 L3_SO2_cloud_fraction       0.000
# 67           L3_SO2_sensor_azimuth_angle       0.000
# 68            L3_SO2_sensor_zenith_angle       0.000
# 69            L3_SO2_solar_azimuth_angle       0.000
# 70             L3_SO2_solar_zenith_angle       0.000
#
# [71 rows x 2 columns]

# %% [markdown]
# Can you directly apply the model to the test data?
# No, not directly, because the test data does not contain the target or the target-related features. Without these features, your model will not work as intended.
# What are the implications?
#
#     Your model has learned to make predictions based on the target and related features (like target_max, target_min).
#     Since these features are absent in the test set, your model will not have the necessary information to generate predictions for the target variable on the test set.

# %% [markdown]
# To resume, I did this first baseline model that is overfitting (train vs. validation).
# Targets/ target min/ target max/ target count/ targe variance: these 4 features are present in the train data but are these columns do not exist in test data. I have around 30000 entries and 68 columns after dropping these 4 features from my train data while I have  16000 entries 70 olumns for the test. the  features dont exist here. Considering that I want to predict the PM2 particle concentrate usig The Sentinel-5 Precursor mission instrument which collects data useful for assessing air quality.How  can I imputate these 4 features to my test dataset ? what would be the most relevant approach ?
